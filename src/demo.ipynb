# %%
# NOTE: have to run the following line to enable animation in Jupyter notebook running on VS code
# %matplotlib widget  

# reload to  make sure the updates are shown
import animation, sort_funcs
from importlib import reload
reload(animation)
reload(sort_funcs)

from animation import run_animation
from sort_funcs import gen_bubble_sort, gen_insertion_sort, gen_merge_sort, gen_quick_sort

from pathlib import Path

video_folder = Path().cwd().joinpath('../saved_animation_videos')
assert video_folder.exists()

# %% [markdown]
# show all the 4 sorting functions animation

# %%
anim_all = run_animation(gen_bubble_sort, gen_insertion_sort, gen_merge_sort, gen_quick_sort)

# anim_all.save(filename=video_folder / 'all_sorting_funcs.mp4')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# show bubble sort animation

# %%
anim_bubble_sort = run_animation(gen_bubble_sort, n_numbers=16)

# anim_bubble_sort.save(filename=video_folder / 'bubble_sort.mp4')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# show insertion sort animation

# %%
anim_insertion_sort = run_animation(gen_insertion_sort, n_numbers=16)

# anim_insertion_sort.save(filename=video_folder / 'insertion_sort.mp4')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
anim_merge_sort = run_animation(gen_merge_sort, n_numbers=16)

# anim_merge_sort.save(filename=video_folder / 'merge_sort.mp4')
# Out:
# /home/ping/Code/project/sorting-visualizer/src/animation.py:26: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, axs = plt.subplots(1, n_funcs, sharey=True)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# show quicksort animation

# %%
anim_quick_sort = run_animation(gen_quick_sort, n_numbers=16)

# anim_quick_sort.save(filename=video_folder / 'quick_sort.mp4')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
